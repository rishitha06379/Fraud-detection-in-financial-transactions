# %%
import pandas as pd


file_path = "Desktop/Jupyter/MP/balanced SDGAN.csv"


df = pd.read_csv(file_path) 

print(df.head())
# Out:
#    Transaction_Amount  Transaction_Type  Account_Balance  Device_Type  \
# 0               39.79               3.0         93213.17          0.0
# 1                1.19               1.0         75725.25          1.0
# 2               28.96               2.0          1588.96          2.0
# 3              254.32               0.0         76807.20          2.0
# 4               31.28               3.0         92354.66          1.0
#
#    IP_Address_Flag  Previous_Fraudulent_Activity  Daily_Transaction_Count  \
# 0              0.0                           0.0                      7.0
# 1              0.0                           0.0                     13.0
# 2              0.0                           0.0                     14.0
# 3              0.0                           0.0                      8.0
# 4              0.0                           1.0                     14.0
#
#    Avg_Transaction_Amount_7d  Failed_Transaction_Count_7d  Card_Type  \
# ...

# %%
import pandas as pd
from table_evaluator import TableEvaluator


original_data = pd.read_csv(r"Desktop/Jupyter/MP/processed_fraud_data.csv")
synthetic_data = pd.read_csv(r"Desktop/Jupyter/MP/balanced SDGAN.csv") 


categorical_columns = ['Device_Type', 'Transaction_Type', 'Card_Type', 'Authentication_Method']


min_rows = min(len(original_data), len(synthetic_data))
original_data_sampled = original_data.sample(n=min_rows, random_state=42)
synthetic_data_sampled = synthetic_data.sample(n=min_rows, random_state=42)


table_evaluator = TableEvaluator(original_data_sampled, synthetic_data_sampled, cat_cols=categorical_columns)


table_evaluator.visual_evaluation()


table_evaluator.plot_cumulative_difference()


table_evaluator.plot_distribution_comparison()
# Out:
# C:\Users\Devendra\AppData\Local\Programs\Python\Python312\Lib\site-packages\table_evaluator\table_evaluator.py:270: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(axes[i].get_xticklabels(), rotation='vertical')
# C:\Users\Devendra\AppData\Local\Programs\Python\Python312\Lib\site-packages\table_evaluator\table_evaluator.py:270: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(axes[i].get_xticklabels(), rotation='vertical')
# C:\Users\Devendra\AppData\Local\Programs\Python\Python312\Lib\site-packages\table_evaluator\table_evaluator.py:270: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(axes[i].get_xticklabels(), rotation='vertical')
# ...
